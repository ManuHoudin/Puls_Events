# %% [markdown]
# # Projet Puls_Events

# %%
# Récupération des données par API

# Récupération des agendas concernés par la région Bretagne via l'API OpenAgenda
import os

import pandas as pd
import requests
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.environ["OPENAGENDA_API_KEY"]
load_dotenv()

url = "https://api.openagenda.com/v2/agendas"

params = {
    "search": "Bretagne",
    "official": 1,
    "size": 100,
    "if[]": ["uid", "title", "description", "slug"],
}

headers = {
    "key": API_KEY,
}

response = requests.get(url, params=params, headers=headers, timeout=30)
response.raise_for_status()

agendas = response.json()["agendas"]
df_agendas = pd.DataFrame(agendas)

display(df_agendas)
# Out:
#          uid                                              image  \
# 0   82540281  https://img.openagenda.com/main/685cb9c0ecec4c...
# 1   38199897  https://img.openagenda.com/main/20e1e0c7927f46...
# 2   29692358  https://img.openagenda.com/main/87ee67f72cad49...
# 3   76975966  https://img.openagenda.com/main/8430afd7916649...
# 4   19632221  https://img.openagenda.com/main/d5dea530c7a842...
# ..       ...                                                ...
# 95  32032698  https://img.openagenda.com/main/efac0265994b4d...
# 96  33113744  https://img.openagenda.com/main/bd14bbd21ff348...
# 97  34742307  https://img.openagenda.com/main/898c22eab00c43...
# 98  35777956  https://img.openagenda.com/main/634c4ffd2eff4e...
# 99  35944609  https://img.openagenda.com/main/0355f66326084b...
#
#                                           description  official  \
# 0   Pôle Étudiant pour l'Innovation, le Transfert ...      True
# 1   L’association Bretagne musées – Réseau des mus...      True
# 2             Les événements des 40 salles du réseau.      True
# 3   Retrouvez ici tous les événements culturels de...      True
# 4   Tous les événements du collège doctoral de Bre...      True
# ..                                                ...       ...
# 95  Les bibliothèques de l'université organisent d...      True
# 96  Séminaires et colloques de l'Université Paris-...      True
# 97  L'agenda des manifestations culturelles et de ...      True
# 98  La culture, les gens, les lieux, les débats, l...      True
# 99  Agenda des contributeurs du Petit Agenda.\nLes...      True
#
#                                         title                          slug
# 0                             Pépite Bretagne               pepite-bretagne
# 1                             Bretagne musées                bretagnemusees
# 2                           Bretagne en Scène             bretagne-en-scene
# 3               Institut Culturel de Bretagne                           icb
# 4                Collège doctoral de Bretagne  college-doctoral-de-bretagne
# ..                                        ...                           ...
# 95       Bibliothèques - Université de Rennes     bibliotheques-univ-rennes
# 96  Agenda de la recherche et de l'innovation            upsaclay-recherche
# 97                 Agenda: Sortir à Chantepie     agenda-sortir-a-chantepie
# 98                   La Palestine à l'Affiche                     palestine
# 99                 Contributeurs Petit Agenda    contributeurs-petit-agenda
#
# [100 rows x 6 columns]

# %%
# Récupération des événements pour chaque agenda

import time
import json
import numpy as np

load_dotenv()

DATE_MIN = "2025-08-01T00:00:00+02:00"

def recuperer_evenements_agenda(agenda_uid):
    url = f"https://api.openagenda.com/v2/agendas/{agenda_uid}/events"

    params_base = {
        "relative[]": ["current", "upcoming"],
        "timings[gte]": DATE_MIN,
        "monolingual": "fr",
        "detailed": 1,
        "size": 300,
        "sort": "timings.asc",
    }

    evenements = []
    after = None
    

    while True:
        params = params_base.copy()

        if after is not None:
            params["after[]"] = after

        response = requests.get(
            url,
            headers=headers,
            params=params,
            timeout=30,
        )
        response.raise_for_status()

        resultat = response.json()
        evenements.extend(resultat["events"])

        after = resultat.get("after")
        if after is None:
            break

    return evenements


tous_evenements = []

for agenda in df_agendas.itertuples(index=False):
    agenda_uid = agenda.uid
    evenements = recuperer_evenements_agenda(agenda_uid)

    # Conserve la provenance de chaque événement.
    for evenement in evenements:
        evenement["agenda_uid_source"] = agenda_uid
        evenement["agenda_titre_source"] = agenda.title

    tous_evenements.extend(evenements)

    # Évite d'enchaîner les appels trop vite.
    time.sleep(0.1)

df_filtre_api = pd.json_normalize(tous_evenements)

colonne_region = "location.region"
region_cible = "Bretagne"

if colonne_region not in df_filtre_api.columns:
    raise KeyError(f"Colonne région absente : {colonne_region}")

masque_region = (
    df_filtre_api[colonne_region]
    .astype("string")
    .str.strip()
    .str.casefold()
    .eq(region_cible.casefold())
)

df_filtre_api = df_filtre_api.loc[masque_region].copy()

# Normalisation explicite du type après l'aplatissement JSON
def est_booleen_compatible(valeur):
    if isinstance(valeur, (bool, np.bool_)):
        return True

    if isinstance(valeur, (int, float, np.integer, np.floating)):
        return valeur in (0, 1)

    if isinstance(valeur, str):
        return valeur.strip().lower() in {
            "true", "false", "1", "0", "oui", "non"
        }

    return False


def convertir_en_booleen(valeur):
    if valeur is None or (isinstance(valeur, float) and np.isnan(valeur)):
        return pd.NA

    if isinstance(valeur, str):
        valeur = valeur.strip().lower()

    return valeur in (True, 1, 1.0, "true", "1", "oui")


colonnes_booleennes = []

for colonne in df_filtre_api.columns:
    valeurs = df_filtre_api[colonne].dropna()

    if not valeurs.empty and valeurs.map(est_booleen_compatible).all():
        df_filtre_api[colonne] = (
            df_filtre_api[colonne]
            .map(convertir_en_booleen)
            .astype("boolean")
        )
        colonnes_booleennes.append(colonne)

print("Colonnes converties en booléen :", colonnes_booleennes)

# La colonne registration mélange des booléeens et du texte, donc on la convertit en chaîne de caractères pour éviter les erreurs de type.
df_filtre_api["registration"] = (
    df_filtre_api["registration"]
    .astype("string")
)

# La colonne tags mélange des structures json et des valeurs simples
def serialiser_json(valeur):
    if valeur is None or valeur is pd.NA:
        return pd.NA

    if isinstance(valeur, float) and np.isnan(valeur):
        return pd.NA

    if isinstance(valeur, (dict, list, tuple)):
        return json.dumps(valeur, ensure_ascii=False, default=str)

    return str(valeur)


colonnes_json = []

for colonne in df_filtre_api.columns:
    valeurs = df_filtre_api[colonne].dropna()

    contient_structure = valeurs.map(
        lambda valeur: isinstance(valeur, (dict, list, tuple))
    ).any()

    if contient_structure:
        df_filtre_api[colonne] = (
            df_filtre_api[colonne]
            .map(serialiser_json)
            .astype("string")
        )
        colonnes_json.append(colonne)

print("Colonnes converties en JSON texte :", colonnes_json)

df_filtre_api.to_parquet(
    "data/parquet_sortie/evenements_culturels_filtre.parquet",
    index=False,
)

print(f"{len(df_filtre_api)} événements récupérés")
print(f"{df_filtre_api['agenda_uid_source'].nunique()} agendas interrogés")
# Out:
# Colonnes converties en booléen : ['featured', 'private', 'valid', 'draft', 'accessibility.ii', 'accessibility.hi', 'accessibility.vi', 'accessibility.pi', 'accessibility.mi', 'originAgenda.private', 'originAgenda.official', 'location.state', 'reserve-a-la-communaute-universitaire', 'jaccepte-que-limage-puisse-etre-librement-utilisee-a-la-condition', 'label-ma-classe-nature', 'jatteste', 'types-devenements', 'horaires-non-communiques', 'evenement-recurrent']
# Colonnes converties en JSON texte : ['keywords', 'timings', 'links', 'sourceAgendas', 'extIds', 'image.variants', 'location.disqualifiedDuplicates', 'location.duplicateCandidates', 'location.links', 'location.tags', 'location.extIds', 'thematique', 'type-devenement', 'conditions-de-participation', 'theme-jep', 'type-de-public', 'specificites', 'location.protections-appellation-et-labels', 'location.types-de-lieu', 'thematiques-info-jeunes', 'theme-jnarchi', 'location.types-de-lieux', 'categories', 'element-patrimoine-culturel-immateriel', 'theme-bicentenaire', 'tarif', 'public', 'organisation', 'type-de-public-vise', 'votre-msa', 'etat-de-la-lite-9848816', 'la-structure-da-37760576', 'infradispo', 'thematiques', 'espace-nuit-com-81583803', 'activites', 'tarifs-conditions-de-paticpation']
# 2548 événements récupérés
# 47 agendas interrogés

# %%
# Récupération des données par download direct

import pandas as pd

# Chargement des sources
fichier_source = "Data/evenements-publics-openagenda.csv"


for bloc in pd.read_csv(
    fichier_source,
    sep=";",
    chunksize=10_000,
    encoding="utf-8"
):
    display(bloc.head())
    print(bloc.columns.tolist())
    break
# Out:
#    Identifiant                                            Slug  \
# 0     12413663         centre-social-st-rambert-dalbon-5148959
# 1     75551745        coupe-de-normandie-vtt-25-septembre-2021
# 2     87153658  un-deux-trad-invite-les-tralala-lovers-8266071
# 3     35021962                           totalement-90-6588587
# 4     71691788        atelier-signer-avec-bebe-avec-laure-giry
#
#                                        URL canonique  \
# 0  https://openagenda.com/tootsweet/events/centre...
# 1  https://openagenda.com/tootsweet/events/coupe-...
# 2  https://openagenda.com/tootsweet/events/un-deu...
# 3  https://openagenda.com/tootsweet/events/totale...
# 4  https://openagenda.com/issy-com/events/atelier...
#
#                                                Titre  \
# 0                   Centre social St Rambert d'Albon
# 1  Coupe de Normandie VTT - 25 septembre 2021 - F...
# 2           Un, deux, trad invite les Tralala Lovers
# 3                                      Totalement 90
# 4       Atelier « Signer avec bébé » avec Laure Giry
#
#                                          Description  \
# 0      organisé par Centre social St Rambert d'Albon
# 1  Coupe de Normandie et Trophée Régional des Jeu...
# 2                avec Tralala Lovers et Viendez-Voir
# 3  WORLDS APART, LARUSSO, INDRA, BORIS, YANNICK E...
# 4  Séance N°1 sur 2, pour découvrir la communicat...
#
#                                   Description longue  \
# 0  <p>Atelier de danses "Folk"</p>\n<p></p>\n<p>A...
# 1  <p>L'association Vélo Jeunes Aventure organise...
# 2  <p>Le "fameux" bal de Mirecourt est enfin de r...
# 3  <p>Totalement 90 accueillera le chanteur Boris...
# 4                                                NaN
#
#           Détail des conditions  \
# 0                       Gratuit
# 1    pass sanitaire obligatoire
# 2                           10€
# 3          Tarifs: de 35€ à 45€
# 4  Sur réservation auprès d’A3N
#
#                                            Mots clés  \
# 0                    breton,bretone,danse,atelier,26
# 1              sport,vtt,feuguerolles bully,calvados
# 2             baltrad,balfolk,danse,chant,musique,88
# 3  chanson,spectacle,show,Longjumeau,Essonne,Ile ...
# 4  signer,bébé,gestuelle bébé,communication avec ...
#
#                                                Image Crédits image  ...  \
# 0                                                NaN           NaN  ...
# 1  https://cibul.s3.amazonaws.com/60a782a88d1e433...           NaN  ...
# 2  https://cibul.s3.amazonaws.com/07ad84a33c24458...           NaN  ...
# 3  https://cibul.s3.amazonaws.com/9f486cc452114f1...           NaN  ...
# 4  https://cibul.s3.amazonaws.com/event_atelier-s...           NaN  ...
#
#   Agenda d'origine (uid) Contributeur: Email Contributeur: Téléphone  \
# 0             82566953.0                 NaN                     NaN
# 1             94552197.0                 NaN                     NaN
# 2             82566953.0                 NaN                     NaN
# 3             15004001.0                 NaN                     NaN
# 4             80515007.0                 NaN                     NaN
#
#   Contributeur: Nom Contributeur: Fonction Contributeur: organisation  \
# 0               NaN                    NaN                        NaN
# 1               NaN                    NaN                        NaN
# 2               NaN                    NaN                        NaN
# 3               NaN                    NaN                        NaN
# 4               NaN                    NaN                        NaN
#
#   Catégorie         Nom du pays  \
# 0       NaN                 NaN
# 1       NaN  France (Métropole)
# 2       NaN                 NaN
# 3       NaN  France (Métropole)
# 4       NaN  France (Métropole)
#
#                                         Registration  \
# 0                                                NaN
# 1  [{"type": "link", "value": "http://www.normand...
# 2                                                NaN
# 3     [{"type": "phone", "value": "01 69 09 09 09"}]
# 4  [{"type": "phone", "value": "06 81 91 43 44"},...
#
#                                   Liens additionnels
# 0                                                NaN
# 1                                                NaN
# 2  [{"data": {"author_url": "https://www.youtube....
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 56 columns]
# ['Identifiant', 'Slug', 'URL canonique', 'Titre', 'Description', 'Description longue', 'Détail des conditions', 'Mots clés', 'Image', 'Crédits image', 'Aperçu', 'Image source', 'Dernière mise à jour', 'Résumé horaires', 'Première date - Début', 'Première date - Fin', 'Dernière date - Début', 'Dernière date - Fin', 'Horaires détaillés', "Code d'accessibilité", 'Accessibilité', 'Identifiant du lieu', 'Coordonnées géographiques', 'Nom du lieu', 'Adresse', 'Arrondissement', 'Code INSEE', 'Code postal', 'Ville', 'Département', 'Région', 'Pays', 'Image du lieu', "Crédits de l'image du lieu", 'Téléphone du lieu', 'Site web du lieu', 'Liens du lieu', 'Tags du lieu', 'Description du lieu', 'Accès / Itinéraire', 'Événement physique ou en ligne', "Lien d'accès en ligne", "État de l'événement", 'Age minimum', 'Age maximum', "Agenda d'origine (titre)", "Agenda d'origine (uid)", 'Contributeur: Email', 'Contributeur: Téléphone', 'Contributeur: Nom', 'Contributeur: Fonction', 'Contributeur: organisation', 'Catégorie', 'Nom du pays', 'Registration', 'Liens additionnels']

# %%
# conversion en fichiers parquet
for i, bloc in enumerate(pd.read_csv(fichier_source,  sep=";", chunksize=100_000)):
    bloc.to_parquet(f"data/parquet_sortie/part-{i:04d}.parquet", index=False)

# %%
# Analyse du fichier parquet
df = pd.read_parquet("data/parquet_sortie/part-0000.parquet")
df.describe()
# Out:
#         Identifiant  Identifiant du lieu   Age minimum   Age maximum  \
# count  1.000000e+05         9.977200e+04  16093.000000  22098.000000
# mean   4.995233e+07         5.026781e+07      9.558069     79.788216
# std    2.882509e+07         2.882240e+07      6.492012     37.267035
# min    1.225000e+03         2.700000e+03      1.000000      1.000000
# 25%    2.496990e+07         2.519298e+07      6.000000     80.000000
# 50%    4.993728e+07         5.031024e+07      8.000000     99.000000
# 75%    7.486513e+07         7.526018e+07     12.000000     99.000000
# max    9.999874e+07         9.999928e+07     75.000000    121.000000
#
#        Agenda d'origine (uid)  Contributeur: Email  Contributeur: Téléphone  \
# count            9.923400e+04                  0.0                      0.0
# mean             3.974640e+07                  NaN                      NaN
# std              2.926612e+07                  NaN                      NaN
# min              5.746000e+03                  NaN                      NaN
# 25%              9.977986e+06                  NaN                      NaN
# 50%              3.849588e+07                  NaN                      NaN
# 75%              6.192520e+07                  NaN                      NaN
# max              9.995489e+07                  NaN                      NaN
#
#        Contributeur: Nom  Contributeur: Fonction  Contributeur: organisation  \
# count                0.0                     0.0                         0.0
# mean                 NaN                     NaN                         NaN
# std                  NaN                     NaN                         NaN
# min                  NaN                     NaN                         NaN
# 25%                  NaN                     NaN                         NaN
# 50%                  NaN                     NaN                         NaN
# 75%                  NaN                     NaN                         NaN
# max                  NaN                     NaN                         NaN
#
#        Catégorie
# count        0.0
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %%
# Filtre sur la région et la date

#print(bloc.columns.tolist())
df_filtre = df[
    (df["Région"] == "Bretagne") &
    (df["Dernière date - Début"] >= "2025-08-01")
].copy()

df_filtre.to_parquet("data/parquet_sortie/part-0000-filtre.parquet", index=False)

# Suppression des identifiants
df_filtre = df_filtre.drop(columns=[df_filtre.columns[0], df_filtre.columns[21]]).copy()

df_filtre.head()
df_filtre.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1050 entries, 2130 to 98848
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Slug                            1050 non-null   str
#  1   URL canonique                   1050 non-null   str
#  2   Titre                           1039 non-null   str
#  3   Description                     1039 non-null   str
#  4   Description longue              936 non-null    str
#  5   Détail des conditions           625 non-null    str
#  6   Mots clés                       520 non-null    str
#  7   Image                           968 non-null    str
#  8   Crédits image                   558 non-null    str
#  9   Aperçu                          968 non-null    str
#  10  Image source                    968 non-null    str
#  11  Dernière mise à jour            1050 non-null   str
#  12  Résumé horaires                 1050 non-null   str
#  13  Première date - Début           1050 non-null   str
#  14  Première date - Fin             1050 non-null   str
#  15  Dernière date - Début           1050 non-null   str
#  16  Dernière date - Fin             1050 non-null   str
#  17  Horaires détaillés              1050 non-null   str
#  18  Code d'accessibilité            196 non-null    str
#  19  Accessibilité                   196 non-null    str
#  20  Coordonnées géographiques       1050 non-null   str
#  21  Nom du lieu                     1050 non-null   str
#  22  Adresse                         1050 non-null   str
#  23  Arrondissement                  565 non-null    str
#  24  Code INSEE                      1007 non-null   str
#  25  Code postal                     1038 non-null   str
#  26  Ville                           1049 non-null   str
#  27  Département                     1048 non-null   str
#  28  Région                          1050 non-null   str
#  29  Pays                            1050 non-null   str
#  30  Image du lieu                   223 non-null    str
#  31  Crédits de l'image du lieu      182 non-null    str
#  32  Téléphone du lieu               227 non-null    str
#  33  Site web du lieu                257 non-null    str
#  34  Liens du lieu                   136 non-null    str
#  35  Tags du lieu                    209 non-null    str
#  36  Description du lieu             281 non-null    str
#  37  Accès / Itinéraire              100 non-null    str
#  38  Événement physique ou en ligne  1050 non-null   str
#  39  Lien d'accès en ligne           72 non-null     str
#  40  État de l'événement             1050 non-null   str
#  41  Age minimum                     119 non-null    float64
#  42  Age maximum                     150 non-null    float64
#  43  Agenda d'origine (titre)        1050 non-null   str
#  44  Agenda d'origine (uid)          1050 non-null   float64
#  45  Contributeur: Email             0 non-null      float64
#  46  Contributeur: Téléphone         0 non-null      float64
#  47  Contributeur: Nom               0 non-null      float64
#  48  Contributeur: Fonction          0 non-null      float64
#  49  Contributeur: organisation      0 non-null      float64
#  50  Catégorie                       0 non-null      float64
#  51  Nom du pays                     1050 non-null   str
#  52  Registration                    544 non-null    str
#  53  Liens additionnels              241 non-null    str
# dtypes: float64(9), str(45)
# memory usage: 3.1 MB

# %% [markdown]
# # Reprise du traitement sur le df issu de l'API

# %%
print(df_filtre_api.dtypes)
# Out:
# longDescription                         str
# country                                 str
# featured                            boolean
# private                             boolean
# keywords                             string
#                                      ...
# tarifs-conditions-de-paticpation     string
# types-devenements                   boolean
# horaires-non-communiques            boolean
# evenement-recurrent                 boolean
# prix                                    str
# Length: 242, dtype: object

# %%
df_filtre_api.count()
# Out:
# longDescription                     2519
# country                             2548
# featured                            2548
# private                             2548
# keywords                            1271
#                                     ...
# tarifs-conditions-de-paticpation       3
# types-devenements                      3
# horaires-non-communiques               2
# evenement-recurrent                    3
# prix                                   2
# Length: 242, dtype: int64

# %%
# Tests unitaires
df_test = pd.read_parquet("data/parquet_sortie/evenements_culturels_filtre.parquet")
print(df_test.head())
print(df_test.shape)
print("Régions filtrées : "+ df_test["location.region"].unique())

# Vérification : True si toutes les dates respectent la condition
seuil_date = pd.Timestamp(DATE_MIN)

def possede_une_occurrence_apres_seuil(timings_json):
    timings = json.loads(timings_json)

    return any(
        pd.Timestamp(creneau["begin"]) >= seuil_date
        for creneau in timings
        if creneau.get("begin")
    )

controle = df_test["timings"].apply(
    possede_une_occurrence_apres_seuil
).all()

print("Contrôle de date :", controle)
# Out:
#                                      longDescription             country  \
# 0  Vous êtes étudiant.e ou jeune diplômé.e, intér...  France (Métropole)
# 1  **MARDI 22 SEPTEMBRE (18H-20H)**\n------------...  France (Métropole)
# 2  Venez découvrir Fabrik ta pépite lors de la so...  France (Métropole)
# 3  Vous êtes étudiant.e ou jeune diplômé.e, intér...  France (Métropole)
# 4  Venez découvrir Fabrik ta pépite lors de la so...  France (Métropole)
#
#    featured  private                                           keywords  \
# 0     False    False  ["entrepreneuriat", "étudiant", "création d'ac...
# 1     False    False                                               <NA>
# 2     False    False                                               <NA>
# 3     False    False  ["entrepreneuriat", "étudiant", "création d'ac...
# 4     False    False                                               <NA>
#
#                     dateRange      timezone     imageCredits  \
# 0    Jeudi 3 septembre, 12h00  Europe/Paris  Pépite Bretagne
# 1   Mardi 22 septembre, 18h00  Europe/Paris              NaN
# 2  29 septembre et 13 octobre  Europe/Paris              NaN
# 3      Jeudi 1 octobre, 12h00  Europe/Paris  Pépite Bretagne
# 4             6 et 13 octobre  Europe/Paris              NaN
#
#                                          description  \
# 0  Nous répondons à toutes vos questions sur la c...
# 1  Découvrez les actions et les dispositifs propo...
# 2  Envie de rencontrer de nouvelles personnes, de...
# 3  Nous répondons à toutes vos questions sur la c...
# 4  Envie de rencontrer de nouvelles personnes, de...
#
#                                                title  ...  \
# 0                         Permanence Pépite Bretagne  ...
# 1                        Entreprendre à l'Université  ...
# 2  Soirée de lancement Fabrik ta pépite – Campus ...  ...
# 3                         Permanence Pépite Bretagne  ...
# 4  Soirée de lancement Fabrik ta pépite – Campus ...  ...
#
#   precisez-les-equipements-de-la-salle-polyvalente-jeux-de-societe-livres-jeunesse-ballons-etc  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    autres-types-despace-nuit-eventuellement-non-listes-ci-dessus  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   thematiques-specifiques-bu  category-group titre-de-levemement-resume  \
# 0                        NaN             NaN                        NaN
# 1                        NaN             NaN                        NaN
# 2                        NaN             NaN                        NaN
# 3                        NaN             NaN                        NaN
# 4                        NaN             NaN                        NaN
#
#    tarifs-conditions-de-paticpation types-devenements  \
# 0                              <NA>              <NA>
# 1                              <NA>              <NA>
# 2                              <NA>              <NA>
# 3                              <NA>              <NA>
# 4                              <NA>              <NA>
#
#   horaires-non-communiques  evenement-recurrent prix
# 0                     <NA>                 <NA>  NaN
# 1                     <NA>                 <NA>  NaN
# 2                     <NA>                 <NA>  NaN
# 3                     <NA>                 <NA>  NaN
# 4                     <NA>                 <NA>  NaN
#
# [5 rows x 242 columns]
# (2548, 242)
# <ArrowStringArray>
# ['Régions filtrées : Bretagne']
# Length: 1, dtype: str
# Contrôle de date : True

# %%
# Nettoyage des données
def valeurs_manquantes(serie):
    if pd.api.types.is_string_dtype(serie) or serie.dtype == "object":
        return serie.isna() | serie.astype("string").str.strip().eq("")
    return serie.isna()

rapport_colonnes = pd.DataFrame({
    "type": df_filtre_api.dtypes.astype(str),
    "valeurs_manquantes": {
        colonne: valeurs_manquantes(df_filtre_api[colonne]).sum()
        for colonne in df_filtre_api.columns
    },
})

rapport_colonnes["taux_remplissage"] = (
    1 - rapport_colonnes["valeurs_manquantes"] / len(df_filtre_api)
).round(3)

rapport_colonnes = rapport_colonnes.sort_values("taux_remplissage")

display(rapport_colonnes)
# Out:
#                       type  valeurs_manquantes  taux_remplissage
# motive              object                2548               0.0
# nm-thematiques      object                2548               0.0
# nm-public           object                2548               0.0
# image              float64                2548               0.0
# tarifs-detail          str                2548               0.0
# ...                    ...                 ...               ...
# timings             string                   0               1.0
# accessibility.ii   boolean                   0               1.0
# location.latitude  float64                   0               1.0
# accessibility.hi   boolean                   0               1.0
# firstTiming.end        str                   0               1.0
#
# [242 rows x 3 columns]

# %%
colonnes_peu_remplies = rapport_colonnes.query(
    "taux_remplissage < 0.10"
)

display(colonnes_peu_remplies)
# Out:
#                                     type  valeurs_manquantes  taux_remplissage
# motive                            object                2548             0.000
# nm-thematiques                    object                2548             0.000
# nm-public                         object                2548             0.000
# image                            float64                2548             0.000
# tarifs-detail                        str                2548             0.000
# ...                                  ...                 ...               ...
# location.disqualifiedDuplicates   string                2420             0.050
# location.access.en                   str                2329             0.086
# location.access.it                   str                2329             0.086
# location.access.es                   str                2329             0.086
# location.access.de                   str                2329             0.086
#
# [132 rows x 3 columns]

# %%
seuil_remplissage = 0.10

colonnes_a_supprimer = rapport_colonnes.index[
    rapport_colonnes["taux_remplissage"] < seuil_remplissage
].tolist()

df_nettoye = (
    df_filtre_api
    .drop(columns=colonnes_a_supprimer)
    .drop_duplicates()
    .copy()
)

# Nettoyage des champs texte
colonnes_texte = df_nettoye.select_dtypes(
    include=["object", "string"]
).columns

for colonne in colonnes_texte:
    df_nettoye[colonne] = (
        df_nettoye[colonne]
        .astype("string")
        .str.strip()
        .replace("", pd.NA)
    )

df_nettoye.to_parquet(
    "data/parquet_sortie/evenements_culturels_nettoye.parquet",
    index=False,
)

print("Colonnes supprimées :", colonnes_a_supprimer)
print("Dimensions après nettoyage :", df_nettoye.shape)
# Out:
# Colonnes supprimées : ['motive', 'nm-thematiques', 'nm-public', 'image', 'tarifs-detail', 'nm-diffusion', 'nm-ignorer-heure-debut', 'nm-types', 'nm-gratuit', 'nm-ignorer-heure-fin', 'nm-carte-blanche', 'discipline', 'categorie', 'thematique-tourisme', 'thematique-social-societe', 'thematique-loisirs', 'theme', 'types-de-public', 'cibles', 'musique-du-monde', 'genre', 'thematique-economie', 'thematique-environnement', 'equipement', 'image.originalName', 'image.extension', 'element-patrimoine-culturel-immateriel', 'thematique-patrimoine', 'particularites', 'thematique-culture', 'theme-jnarchi', 'type_devenements', 'thematique-sport', 'organisateur', 'type-de-public-vise', 'champ-art', 'category-group', 'thematiques-specifiques-bu', 'conseil', 'diffusion-sur-le-site-info-jeunes-france', 'thematiques-info-jeunes', 'votre-msa', 'evenement-recurrent', 'types-devenements', 'horaires-non-communiques', 'titre-de-levemement-resume', 'autres-types-despace-nuit-eventuellement-non-listes-ci-dessus', 'tarifs-conditions-de-paticpation', 'prix', 'observations-eventuelles-relatives-a-des-contraintes-liees-a-la-configuration-du-site', 'equipe-de-recherche', 'autres-infrastructures-et-equipements-eventuellement-non-listes-ci-dessus', 'label-ma-classe-nature', 'precisez-le-materiel-pedagogique-de-la-ou-des-salles-de-classe-tableau-fournitures-scolaires', 'categories', 'activites-proposees-par-la-structure', 'precisez-les-equipements-de-la-salle-polyvalente-jeux-de-societe-livres-jeunesse-ballons-etc', 'materiel-disponible', 'biodiversite', 'onlineAccessLink', 'salles-classes', 'avis', 'valises', 'structure-daccu-27031045', 'infirmerie', 'etat-de-la-lite-9848816', 'acc-struct', 'sante-et-hygiene-nombre-de-toilettes', 'secours', 'separation', 'pasaison', 'organisation', 'reglements', 'type-derp', 'je-mengage-a-pr-92451288', 'principaux-sites-et-activites-culturelles-et-touristiques-a-proximite-de-la-structure-daccueil-et-dhebergement', 'activites', 'jatteste', 'espace-nuit-com-81583803', 'periode-douverture-annuelle-de-la-structure-pour-laccueil-des-eleves-dans-le-cadre-de-voyages-scolaires', 'la-structure-da-37760576', 'infradispo', 'categorie-derp', 'personnels-employes-de-facon-permanente-information-non-publique', 'rangements', 'mobilier', 'charger-ici-le-document-emis-par-la-commission-consultative-departementale-de-securite-et-daccessibilite.originalName', 'charger-ici-le-document-emis-par-la-commission-consultative-departementale-de-securite-et-daccessibilite.extension', 'joindre-une-photo-des-toilettes.filename', 'photographie-de-la-structure-champs-temporaire.originalName', 'joindre-une-photo-des-toilettes.originalName', 'joindre-une-photo-des-toilettes.extension', 'photographie-de-la-structure-champs-temporaire.extension', 'photographie-de-la-structure-champs-temporaire.filename', 'photographie-de-lespace-nuit.filename', 'photographie-de-lespace-nuit.extension', 'la-structure-da-16375307', 'date-du-dernier-passage-de-la-commission-consultative-departementale-de-securite-et-daccessibilite', 'capacite-daccueil-nombre-de-lits-pour-les-adultes-assurant-lencadrement', 'capacite-daccueil-nombre-de-lits-pour-les-eleves', 'draps', 'polyvalente', 'thematiques', 'la-structure-da-57621442', 'si-le-batiment-est-equipe-de-salles-de-classe-independantes-nombre-et-capacite-de-chaque-salle', 'la-structure-da-31632389', 'date-de-lautorisation-municipale-douverture', 'refectoire', 'photographie-dune-salle-de-classe.originalName', 'photographie-dune-salle-de-classe.extension', 'photographie-dune-salle-de-classe.filename', 'photographie-de-lespace-nuit.originalName', 'charger-ici-le-document-emis-par-la-commission-consultative-departementale-de-securite-et-daccessibilite.filename', 'joindre-une-photo-des-douches.originalName', 'joindre-une-photo-des-douches.extension', 'joindre-une-photo-des-douches.filename', 'nombre-de-douches', 'sportives', 'extIds', 'evenement', 'campus', 'location.mergedIn', 'location.types-de-lieux', 'theme-bicentenaire', 'location.dup ...
# Dimensions après nettoyage : (2548, 110)

# %% [markdown]
# # Génération des embeddings

# %%
import os
from pathlib import Path
import numpy as np

from dotenv import load_dotenv
from mistralai.client import Mistral

from matplotlib import pyplot as plt
from sklearn.manifold import TSNE

from langchain_text_splitters import RecursiveCharacterTextSplitter

load_dotenv(Path.cwd() / ".env")
api_key = os.environ["MISTRAL_API_KEY"]

# Colonnes utiles à la recherche sémantique
colonnes_embedding = [
   "title",
   "description",
   "longDescription",
   "keywords",
   "location.city",
   "location.region",
]

# Une ligne DataFrame devient un document texte
documents = (
    df_nettoye[colonnes_embedding]
    .fillna("")
    .astype(str)
    .apply(
        lambda ligne: "\n".join(
            f"{colonne}: {valeur.strip()}"
            for colonne, valeur in ligne.items()
            if valeur.strip()
        ),
        axis=1,
    )
)

# Chunking et traitement des documents vides
mask = documents.str.strip().ne("")
documents = documents.loc[mask]

# Découpe les documents longs avant leur vectorisation.
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1_000,
    chunk_overlap=150,
    separators=["\n\n", "\n", ". ", " ", ""],
)

chunks = []

for index_evenement, texte in documents.items():
    for numero_chunk, texte_chunk in enumerate(splitter.split_text(texte)):
        chunks.append({
            "index_evenement": index_evenement,
            "numero_chunk": numero_chunk,
            "texte_chunk": texte_chunk,
        })

df_embeddings = pd.DataFrame(chunks)

documents = df_embeddings["texte_chunk"].tolist()

# Appels en lots pour traiter les événements proprement
taille_lot = 100
embeddings = []

with Mistral(api_key=api_key) as mistral:
    for debut in range(0, len(documents), taille_lot):
        lot = documents[debut:debut + taille_lot]

        reponse = mistral.embeddings.create(
            model="mistral-embed",
            inputs=lot,
        )

        embeddings.extend(
            item.embedding
            for item in sorted(
                reponse.data, 
                key=lambda item: item.index if item.index is not None else -1,)
        )

# Conserve le texte envoyé et son vecteur sur chaque événement
df_embeddings["embedding"] = embeddings

df_embeddings.to_parquet(
    "data/parquet_sortie/evenements_embeddings_mistral.parquet",
    index=False,
)

print(f"{len(df_embeddings)} embeddings créés.")
print(f"Dimension d'un embedding : {len(embeddings[0])}")
# Out:
# 3784 embeddings créés.
# Dimension d'un embedding : 1024

# %%
df_embeddings.head()
# Out:
#    index_evenement  numero_chunk  \
# 0                0             0
# 1                2             0
# 2                2             1
# 3                3             0
# 4                3             1
#
#                                          texte_chunk  \
# 0  title: Permanence Pépite Bretagne\ndescription...
# 1  title: Entreprendre à l'Université\ndescriptio...
# 2  **\> Table ronde : 3 questions à nos alumnis a...
# 3  title: Soirée de lancement Fabrik ta pépite – ...
# 4  ### Pourquoi venir à la soirée de lancement ?\...
#
#                                            embedding
# 0  [-0.0234527587890625, 0.0193328857421875, 0.03...
# 1  [-0.0266876220703125, 0.02288818359375, 0.0339...
# 2  [-0.0281982421875, 0.047607421875, 0.031402587...
# 3  [-0.0285491943359375, 0.01806640625, 0.0489196...
# 4  [-0.038299560546875, 0.01241302490234375, 0.04...

# %%
# Réduction de dimension pour les embeddings Mistral

# Conversion de la colonne contenant les vecteurs Mistral en matrice NumPy
matrice_embeddings = np.asarray(df_embeddings["embedding"].tolist())

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    max_iter=1_000,
    random_state=42,
)

embeddings_2d = tsne.fit_transform(matrice_embeddings)

df_embeddings["tsne_x"] = embeddings_2d[:, 0]
df_embeddings["tsne_y"] = embeddings_2d[:, 1]

plt.figure(figsize=(12, 8))
plt.scatter(
    df_embeddings["tsne_x"],
    df_embeddings["tsne_y"],
    alpha=0.65,
)

plt.title("Projection t-SNE des événements")
plt.xlabel("Dimension t-SNE 1")
plt.ylabel("Dimension t-SNE 2")
plt.show()

# %%
import os
import hashlib

key = os.environ["MISTRAL_API_KEY"]

print("Clé présente :", bool(key))
print("Préfixe :", key[:8])
print(
    "Empreinte :",
    hashlib.sha256(key.encode()).hexdigest()[:12]
)
# Out:
# Clé présente : True
# Préfixe : 2pN4XmbF
# Empreinte : 75b0325acf67
